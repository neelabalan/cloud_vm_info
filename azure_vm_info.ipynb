# %% [markdown]
# # Reference
#
# - https://learn.microsoft.com/en-us/rest/api/cost-management/retail-prices/azure-retail-prices
# - https://azureprice.net
# - https://azure.microsoft.com/en-in/pricing/details/virtual-machines/linux/
# - https://github.com/doitintl/azure-instances.info

# %%
import requests
import pandas as pd

# %%
azure_vm_url = 'https://azure.microsoft.com/api/v3/pricing/virtual-machines/page/details/linux/?culture=en-in&showLowPriorityOffers=false'

# %%
response = requests.get(azure_vm_url)

# %%
response
# Out:
# <Response [200]>

# %%
response_json = response.json()

# %%
vm_info = response_json['attributesByOffer']

# %%
vm_info_df = pd.DataFrame(vm_info.values())

# %%
vm_info_df.head()
# Out:
#   series nameLocKey instanceName  cores        category   ram      tier  \
# 0    av2       a1v2        A1 v2      1  generalpurpose   2.0  standard
# 1    av2      a2mv2       A2m v2      2  generalpurpose  16.0  standard
# 2    av2       a2v2        A2 v2      2  generalpurpose   4.0  standard
# 3    av2      a4mv2       A4m v2      4  generalpurpose  32.0  standard
# 4    av2       a4v2        A4 v2      4  generalpurpose   8.0  standard
#
#    hasPayGo  isInPreview  diskSize  ... hasSpot  isVcpu  isConstrainedCore  \
# 0      True        False      10.0  ...    True   False              False
# 1      True        False      20.0  ...    True   False              False
# 2      True        False      20.0  ...    True   False              False
# 3      True        False      40.0  ...    True   False              False
# 4      True        False      40.0  ...    True   False              False
#
#    isBaseVm  activeCores  productId nvMeDisk  gpu fpga pmem
# 0      True          NaN        NaN      NaN  NaN  NaN  NaN
# 1      True          NaN        NaN      NaN  NaN  NaN  NaN
# 2      True          NaN        NaN      NaN  NaN  NaN  NaN
# 3      True          NaN        NaN      NaN  NaN  NaN  NaN
# 4      True          NaN        NaN      NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
vm_info_df.columns
# Out:
# Index(['series', 'nameLocKey', 'instanceName', 'cores', 'category', 'ram',
#        'tier', 'hasPayGo', 'isInPreview', 'diskSize', 'type', 'hasSpot',
#        'isVcpu', 'isConstrainedCore', 'isBaseVm', 'activeCores', 'productId',
#        'nvMeDisk', 'gpu', 'fpga', 'pmem'],
#       dtype='object')

# %%
vm_info_df.to_csv("data/azure_vm_info.csv")

# %%
pricing_url = "https://prices.azure.com/api/retail/prices?$filter=serviceName eq 'Virtual Machines' and armRegionName eq 'southcentralus' and priceType eq 'Consumption'"

response = requests.get(pricing_url).json()
items = response['Items']
next_link =  response.get('NextPageLink')
while(next_link):
	response = requests.get(next_link)
	response_json = response.json()
	if response_json.get('Items'):
		items.extend(response_json.get('Items'))
	next_link =  response_json.get('NextPageLink')

# %%
pricing_df = pd.DataFrame(items)

# %%
pricing_df.head()
# Out:
#   currencyCode  tierMinimumUnits  retailPrice  unitPrice   armRegionName  \
# 0          USD               0.0     4.838000   4.838000  southcentralus
# 1          USD               0.0     0.434000   0.434000  southcentralus
# 2          USD               0.0     1.136479   1.136479  southcentralus
# 3          USD               0.0     0.099000   0.099000  southcentralus
# 4          USD               0.0     0.747906   0.747906  southcentralus
#
#            location    effectiveStartDate  \
# 0  US South Central  2020-08-01T00:00:00Z
# 1  US South Central  2022-06-01T00:00:00Z
# 2  US South Central  2023-02-01T00:00:00Z
# 3  US South Central  2017-05-10T00:00:00Z
# 4  US South Central  2023-02-01T00:00:00Z
#
#                                 meterId            meterName     productId  \
# 0  0016083a-928f-56fd-8eeb-39287dcf676d               E64 v4  DZH318Z0D1L7
# 1  0050211e-db45-538f-b411-4c48804aa0ca        DC8ds_v3 Spot  DZH318Z08NRF
# 2  005bbecd-034c-5d82-b927-1656f77dcb13         D48s v3 Spot  DZH318Z0BPWD
# 3  00888607-2147-4a79-849d-55bbd09dc37d  A8m v2 Low Priority  DZH318Z0BPRJ
# 4  00bdbef3-8af7-58af-a4c4-61e1f0500039         D32s v4 Spot  DZH318Z0CP07
#
#    ...                           productName                 skuName  \
# 0  ...           Virtual Machines Ev4 Series                  E64 v4
# 1  ...                   DCdsv3 Series Linux  standard_DC8ds_v3 Spot
# 2  ...  Virtual Machines DSv3 Series Windows            D48s v3 Spot
# 3  ...           Virtual Machines Av2 Series     A8m v2 Low Priority
# 4  ...  Virtual Machines Dsv4 Series Windows            D32s v4 Spot
#
#         serviceName     serviceId serviceFamily unitOfMeasure         type  \
# 0  Virtual Machines  DZH313Z7MMC8       Compute        1 Hour  Consumption
# 1  Virtual Machines  DZH313Z7MMC8       Compute        1 Hour  Consumption
# 2  Virtual Machines  DZH313Z7MMC8       Compute        1 Hour  Consumption
# 3  Virtual Machines  DZH313Z7MMC8       Compute        1 Hour  Consumption
# 4  Virtual Machines  DZH313Z7MMC8       Compute        1 Hour  Consumption
#
#   isPrimaryMeterRegion         armSkuName      effectiveEndDate
# 0                 True    Standard_E64_v4                   NaN
# 1                 True  Standard_DC8ds_v3                   NaN
# 2                 True   Standard_D48s_v3  2023-02-28T23:59:00Z
# 3                 True    Standard_A8m_v2                   NaN
# 4                 True   Standard_D32s_v4  2023-02-28T23:59:00Z
#
# [5 rows x 22 columns]

# %%
pricing_df.columns
# Out:
# Index(['currencyCode', 'tierMinimumUnits', 'retailPrice', 'unitPrice',
#        'armRegionName', 'location', 'effectiveStartDate', 'meterId',
#        'meterName', 'productId', 'skuId', 'availabilityId', 'productName',
#        'skuName', 'serviceName', 'serviceId', 'serviceFamily', 'unitOfMeasure',
#        'type', 'isPrimaryMeterRegion', 'armSkuName', 'effectiveEndDate'],
#       dtype='object')

# %%
pricing_df.rename({'meterName': 'instanceName'}, axis='columns', inplace=True)

# %%
len(pricing_df)
# Out:
# 3935

# %%
pricing_df = pricing_df[~pricing_df['instanceName'].str.contains('Spot')] 
pricing_df = pricing_df[~pricing_df['instanceName'].str.contains('Priority')]

# %%
len(pricing_df)
# Out:
# 1381

# %%
pricing_df.to_csv("data/azure_vm_pricing.csv")

# %%
final_df = pd.merge(vm_info_df, pricing_df, on='instanceName')

# %%
final_df.head()
# Out:
#   series nameLocKey instanceName  cores        category   ram      tier  \
# 0    av2       a1v2        A1 v2      1  generalpurpose   2.0  standard
# 1    av2       a1v2        A1 v2      1  generalpurpose   2.0  standard
# 2    av2      a2mv2       A2m v2      2  generalpurpose  16.0  standard
# 3    av2      a2mv2       A2m v2      2  generalpurpose  16.0  standard
# 4    av2       a2v2        A2 v2      2  generalpurpose   4.0  standard
#
#    hasPayGo  isInPreview  diskSize  ...                          productName  \
# 0      True        False      10.0  ...          Virtual Machines Av2 Series
# 1      True        False      10.0  ...  Virtual Machines Av2 Series Windows
# 2      True        False      20.0  ...  Virtual Machines Av2 Series Windows
# 3      True        False      20.0  ...          Virtual Machines Av2 Series
# 4      True        False      20.0  ...          Virtual Machines Av2 Series
#
#    skuName       serviceName     serviceId  serviceFamily  unitOfMeasure  \
# 0    A1 v2  Virtual Machines  DZH313Z7MMC8        Compute         1 Hour
# 1    A1 v2  Virtual Machines  DZH313Z7MMC8        Compute         1 Hour
# 2   A2m v2  Virtual Machines  DZH313Z7MMC8        Compute         1 Hour
# 3   A2m v2  Virtual Machines  DZH313Z7MMC8        Compute         1 Hour
# 4    A2 v2  Virtual Machines  DZH313Z7MMC8        Compute         1 Hour
#
#         type_y isPrimaryMeterRegion       armSkuName effectiveEndDate
# 0  Consumption                 True   Standard_A1_v2              NaN
# 1  Consumption                 True   Standard_A1_v2              NaN
# 2  Consumption                 True  Standard_A2m_v2              NaN
# 3  Consumption                 True  Standard_A2m_v2              NaN
# 4  Consumption                 True   Standard_A2_v2              NaN
#
# [5 rows x 42 columns]

# %%
final_df.columns
# Out:
# Index(['series', 'nameLocKey', 'instanceName', 'cores', 'category', 'ram',
#        'tier', 'hasPayGo', 'isInPreview', 'diskSize', 'type_x', 'hasSpot',
#        'isVcpu', 'isConstrainedCore', 'isBaseVm', 'activeCores', 'productId_x',
#        'nvMeDisk', 'gpu', 'fpga', 'pmem', 'currencyCode', 'tierMinimumUnits',
#        'retailPrice', 'unitPrice', 'armRegionName', 'location',
#        'effectiveStartDate', 'meterId', 'productId_y', 'skuId',
#        'availabilityId', 'productName', 'skuName', 'serviceName', 'serviceId',
#        'serviceFamily', 'unitOfMeasure', 'type_y', 'isPrimaryMeterRegion',
#        'armSkuName', 'effectiveEndDate'],
#       dtype='object')

# %%
final_df.to_csv("data/azure_vm.csv")

# %%
final_df[['cores', 'ram', 'unitPrice']].describe()
# Out:
#             cores           ram   unitPrice
# count  952.000000    952.000000  952.000000
# mean    34.144958    314.818803    4.390882
# std     41.495822    765.286474    8.767047
# min      1.000000      0.500000    0.006240
# 25%      8.000000     32.000000    0.629000
# 50%     16.000000    128.000000    2.170000
# 75%     48.000000    384.000000    5.096000
# max    416.000000  11400.000000  138.120000
